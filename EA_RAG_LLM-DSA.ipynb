# %%
### Import Packages
import os
import pandas as pd
import nltk
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# %% [markdown]
# ### Read Files

# %%
### Read All files in a directory that contain "RESULTS" substring.

# Function to read all CSV files containing "RESULTS" in filename from a directory and its subdirectories
def read_csv_files(directory):
    all_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if "RESULTS" in file and file.endswith(".csv"):
                all_files.append(os.path.join(root, file))
    
    # Combine all CSV files into one DataFrame
    combined_df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    return combined_df

# Example usage
directory_path = './DATA/output/dataset1'
combined_df = read_csv_files(directory_path)


combined_df#.head()
# Out:
#                                                question  \
# 0     What computational approach does PAL use to in...
# 1     How does LLaMA's training data preprocessing a...
# 2     In what way does Task2Vec's asymmetric distanc...
# 3     How does Task2Vec ensure its task embeddings a...
# 4     What role do random perturbations play in Dete...
# ...                                                 ...
# 1009  How do the LLaMA models' parameter counts comp...
# 1010  What performance improvements does LLaMA-13B s...
# 1011  What specific challenges do the tasks in Super...
# 1012  What contributions does CodeNet make towards t...
# 1013  How does CodeNet's dataset size and diversity ...
#
#                                                  answer  \
# 0     PAL uses an approach that combines a large lan...
# 1     LLaMA's training data preprocessing and mixtur...
# 2     Task2Vec's asymmetric distance, represented by...
# 3     Task2Vec ensures its task embeddings are invar...
# 4     Random perturbations are used in DetectGPT's m...
# ...                                                 ...
# 1009  The LLaMA models come in several different siz...
# 1010  Based on the provided context, here's a summar...
# 1011  The tasks included in SuperGLUE aim to challen...
# 1012  Based on the information provided, Codenet mak...
# 1013  The CodeNet dataset offers significant advanta...
#
#                                                contexts  \
# 0     ['PAL: Program-aided Language Models\nLuyu Gao...
# 1     ['LLaMA: Open and Efﬁcient Foundation Language...
# 2     ['about the structure of the task. We may ther...
# 3     ['TASK2VEC: Task Embedding for Meta-Learning\n...
# 4     ['Zero-Shot Machine-Generated Text Detection u...
# ...                                                 ...
# 1009  ['HellaSwag (Zellers et al., 2019), WinoGrande...
# 1010  ['HellaSwag (Zellers et al., 2019), WinoGrande...
# 1011  ['Public data: We require that tasks have exis...
# 1012  ['CodeNet: A Large-Scale AI for Code Dataset f...
# 1013  ['CodeNet: A Large-Scale AI for Code Dataset f...
#
#                                            ground_truth                model  \
# 0     PAL leverages large language models (LLMs) to ...  lucataco/qwen1.5-7b
# 1     LLaMA's training data includes a mixture of so...  lucataco/qwen1.5-7b
# 2     The asymmetric distance accounts for task comp...  lucataco/qwen1.5-7b
# 3     By basing the embeddings on the structure of t...  lucataco/qwen1.5-7b
# 4     Random perturbations are used to slightly modi...  lucataco/qwen1.5-7b
# ...                                                 ...                  ...
# 1009  The LLaMA modelsvary in size from 7 billion pa...    01-ai/yi-34b-chat
# 1010  LLaMA-13B outperforms GPT-3 (175B) on most ben...    01-ai/yi-34b-chat
# 1011  The tasks challenge models on various fronts, ...    01-ai/yi-34b-chat
# 1012   By providing a comprehensive dataset with div...    01-ai/yi-34b-chat
# 1013  CodeNet surpasses previous datasets with over ...    01-ai/yi-34b-chat
#
#       context_precision  faithfulness  answer_relevancy  context_recall  \
# 0                   1.0      1.000000          0.712241        1.000000
# 1                   0.0      1.000000          1.000000        0.333333
# 2                   1.0      0.777778          0.792736        1.000000
# 3                   1.0      1.000000          1.000000        1.000000
# 4                   1.0      0.875000          0.931426        1.000000
# ...                 ...           ...               ...             ...
# 1009                0.0      0.285714          0.809094        1.000000
# 1010                1.0      0.866667          0.651096        1.000000
# 1011                1.0      0.666667          0.702388        0.000000
# 1012                1.0      0.666667          0.956133        1.000000
# 1013                1.0      0.444444          0.803370        1.000000
#
#       answer_correctness  answer_similarity
# 0               0.724417           0.897670
# 1               0.510929           0.843718
# 2               0.169576           0.678304
# 3               0.189867           0.759467
# 4               0.393320           0.823280
# ...                  ...                ...
# 1009            0.822851           0.891402
# 1010            0.403623           0.864490
# 1011            0.165375           0.661501
# 1012            0.222002           0.888009
# 1013            0.292516           0.795063
#
# [1014 rows x 11 columns]

# %%
combined_df['contexts'] = combined_df['contexts'].apply(eval)
combined_df['concatenated_contexts'] = combined_df['contexts'].apply(lambda x: ' '.join(x))

# %%
#combined_df["ground_truth"]

# %%
len(combined_df)
# Out:
# 1014

# %%
len(combined_df.dropna())
# Out:
# 918

# %% [markdown]
# ### Drop no-answer rows

# %%
combined_df = combined_df.dropna()

# %% [markdown]
# ### Calculate BLEU, BLEU_Score and ROUGUE_Score

# %%
# %pip install rouge
# %pip install bert_score

# %%
import pandas as pd
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge
from bert_score import score

# Assuming your dataframe is named 'df'

# Function to calculate BLEU score
def calculate_bleu(reference, candidate):
    smoothie = SmoothingFunction().method1
    return sentence_bleu([reference.split()], candidate.split(),
                        weights=(0.25, 0.25, 0.25, 0.25),  # This gives equal weight to 1, 2, 3, and 4-grams
                        smoothing_function=smoothie
                        )

# Function to calculate ROUGE scores
def calculate_rouge(reference, candidate):
    rouge = Rouge()
    scores = rouge.get_scores(candidate, reference)
    return scores[0]['rouge-l']['f']  # Using ROUGE-L F1 score


def calculate_bertscore(references, candidates):
    P, R, F1 = score(candidates, references, lang="en", verbose=False)
    return F1.tolist()  # Return F1 scores as a list

# Apply the functions to create new columns
combined_df['BLEUScore'] = combined_df.apply(lambda row: calculate_bleu(row['ground_truth'], row['answer']), axis=1)
combined_df['ROUGEScore'] = combined_df.apply(lambda row: calculate_rouge(row['ground_truth'], row['answer']), axis=1)

# Calculate BERTScore
references = combined_df['ground_truth'].tolist()
candidates = combined_df['answer'].tolist()
combined_df['BERTScore'] = calculate_bertscore(references, candidates)


# If you want separate columns for different BLEU scores (e.g., BLEU-1, BLEU-2, etc.),
# you can modify the calculate_bleu function and add more columns accordingly.

# Display the updated dataframe
#combined_df.head()
# Out:
# /tmp/ipykernel_3766653/3913079309.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['BLEUScore'] = combined_df.apply(lambda row: calculate_bleu(row['ground_truth'], row['answer']), axis=1)
# /tmp/ipykernel_3766653/3913079309.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['ROUGEScore'] = combined_df.apply(lambda row: calculate_rouge(row['ground_truth'], row['answer']), axis=1)
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /tmp/ipykernel_3766653/3913079309.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df['BERTScore'] = calculate_bertscore(references, candidates)

# %%
combined_df.to_csv("./DATA/output/dataset1/metricsBertBleuRouge.csv", encoding='utf-8', index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming combined_df is already available from the previous steps

# Plot horizontal violin plot for faithfulness for each model
plt.figure(figsize=(12, 6))
sns.violinplot(y='model', x='faithfulness', data=combined_df)
plt.title('Horizontal Violin Plot of Faithfulness by Model')
plt.ylabel('Model')
plt.xlabel('Faithfulness')
plt.tight_layout()
plt.show()

# %%
corr_matrix = combined_df[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity','BLEUScore', 'ROUGEScore', 'BERTScore']].corr()

# Plotting the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Metrics')
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity']].mean().reset_index()

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[['answer_correctness']].mean().reset_index()
average_df = average_df.sort_values(by='answer_correctness', ascending=False)

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[['faithfulness']].mean().reset_index()
average_df = average_df.sort_values(by='faithfulness', ascending=False)

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[['BLEUScore', 'ROUGEScore']].mean().reset_index()
average_df = average_df.sort_values(by='BLEUScore', ascending=False)

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[["faithfulness", "answer_relevancy"]].mean().reset_index()
average_df = average_df.sort_values(by='faithfulness', ascending=False)

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[["faithfulness", 'BERTScore']].mean().reset_index()

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Calculate average values for the specified columns
average_df = combined_df.groupby('model')[['ROUGEScore']].mean().reset_index()

# Melt the DataFrame for easier plotting with seaborn
melted_df = average_df.melt(id_vars='model', var_name='metric', value_name='average_value')

# Plot barplot
plt.figure(figsize=(14, 7))
sns.barplot(x='average_value', y='model', hue='metric', data=melted_df)
plt.title('Average Values of Metrics by Model')
plt.xlabel('Average Value')
plt.ylabel('Model')
plt.legend(title='Metric', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Sample data creation for demonstration
data = {
    'model': [f'Model_{i}' for i in range(1, 31)],
    'value': [i for i in range(1, 31)]  # Replace with your actual values
}

df = pd.DataFrame(data)

# Plot vertical dot plot
plt.figure(figsize=(14, 7))
sns.stripplot(x='model', y='value', data=df, size=8, color='blue', jitter=False)
plt.title('Values for Each Model')
plt.xlabel('Model')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
combined_df
# Out:
#                                                question  \
# 0     What computational approach does PAL use to in...
# 1     How does LLaMA's training data preprocessing a...
# 2     In what way does Task2Vec's asymmetric distanc...
# 3     How does Task2Vec ensure its task embeddings a...
# 4     What role do random perturbations play in Dete...
# ...                                                 ...
# 1009  How do the LLaMA models' parameter counts comp...
# 1010  What performance improvements does LLaMA-13B s...
# 1011  What specific challenges do the tasks in Super...
# 1012  What contributions does CodeNet make towards t...
# 1013  How does CodeNet's dataset size and diversity ...
#
#                                                  answer  \
# 0     PAL uses an approach that combines a large lan...
# 1     LLaMA's training data preprocessing and mixtur...
# 2     Task2Vec's asymmetric distance, represented by...
# 3     Task2Vec ensures its task embeddings are invar...
# 4     Random perturbations are used in DetectGPT's m...
# ...                                                 ...
# 1009  The LLaMA models come in several different siz...
# 1010  Based on the provided context, here's a summar...
# 1011  The tasks included in SuperGLUE aim to challen...
# 1012  Based on the information provided, Codenet mak...
# 1013  The CodeNet dataset offers significant advanta...
#
#                                                contexts  \
# 0     [PAL: Program-aided Language Models\nLuyu Gao*...
# 1     [LLaMA: Open and Efﬁcient Foundation Language ...
# 2     [about the structure of the task. We may there...
# 3     [TASK2VEC: Task Embedding for Meta-Learning\nA...
# 4     [Zero-Shot Machine-Generated Text Detection us...
# ...                                                 ...
# 1009  [HellaSwag (Zellers et al., 2019), WinoGrande ...
# 1010  [HellaSwag (Zellers et al., 2019), WinoGrande ...
# 1011  [Public data: We require that tasks have exist...
# 1012  [CodeNet: A Large-Scale AI for Code Dataset fo...
# 1013  [CodeNet: A Large-Scale AI for Code Dataset fo...
#
#                                            ground_truth                model  \
# 0     PAL leverages large language models (LLMs) to ...  lucataco/qwen1.5-7b
# 1     LLaMA's training data includes a mixture of so...  lucataco/qwen1.5-7b
# 2     The asymmetric distance accounts for task comp...  lucataco/qwen1.5-7b
# 3     By basing the embeddings on the structure of t...  lucataco/qwen1.5-7b
# 4     Random perturbations are used to slightly modi...  lucataco/qwen1.5-7b
# ...                                                 ...                  ...
# 1009  The LLaMA modelsvary in size from 7 billion pa...    01-ai/yi-34b-chat
# 1010  LLaMA-13B outperforms GPT-3 (175B) on most ben...    01-ai/yi-34b-chat
# 1011  The tasks challenge models on various fronts, ...    01-ai/yi-34b-chat
# 1012   By providing a comprehensive dataset with div...    01-ai/yi-34b-chat
# 1013  CodeNet surpasses previous datasets with over ...    01-ai/yi-34b-chat
#
#       context_precision  faithfulness  answer_relevancy  context_recall  \
# 0                   1.0      1.000000          0.712241        1.000000
# 1                   0.0      1.000000          1.000000        0.333333
# 2                   1.0      0.777778          0.792736        1.000000
# 3                   1.0      1.000000          1.000000        1.000000
# 4                   1.0      0.875000          0.931426        1.000000
# ...                 ...           ...               ...             ...
# 1009                0.0      0.285714          0.809094        1.000000
# 1010                1.0      0.866667          0.651096        1.000000
# 1011                1.0      0.666667          0.702388        0.000000
# 1012                1.0      0.666667          0.956133        1.000000
# 1013                1.0      0.444444          0.803370        1.000000
#
#       answer_correctness  answer_similarity  \
# 0               0.724417           0.897670
# 1               0.510929           0.843718
# 2               0.169576           0.678304
# 3               0.189867           0.759467
# 4               0.393320           0.823280
# ...                  ...                ...
# 1009            0.822851           0.891402
# 1010            0.403623           0.864490
# 1011            0.165375           0.661501
# 1012            0.222002           0.888009
# 1013            0.292516           0.795063
#
#                                   concatenated_contexts  BLEUScore  \
# 0     PAL: Program-aided Language Models\nLuyu Gao* ...   0.059525
# 1     LLaMA: Open and Efﬁcient Foundation Language M...   0.022909
# 2     about the structure of the task. We may theref...   0.003070
# 3     TASK2VEC: Task Embedding for Meta-Learning\nAl...   0.011786
# 4     Zero-Shot Machine-Generated Text Detection usi...   0.033141
# ...                                                 ...        ...
# 1009  HellaSwag (Zellers et al., 2019), WinoGrande (...   0.006911
# 1010  HellaSwag (Zellers et al., 2019), WinoGrande (...   0.009220
# 1011  Public data: We require that tasks have existi...   0.002779
# 1012  CodeNet: A Large-Scale AI for Code Dataset for...   0.016094
# 1013  CodeNet: A Large-Scale AI for Code Dataset for...   0.028435
#
#       ROUGEScore  BERTScore
# 0       0.320988   0.912698
# 1       0.243902   0.853357
# 2       0.164948   0.854169
# 3       0.222222   0.885922
# 4       0.257426   0.880344
# ...          ...        ...
# 1009    0.188406   0.847468
# 1010    0.178771   0.848814
# 1011    0.103704   0.826570
# 1012    0.129310   0.854749
# 1013    0.134328   0.854896
#
# [918 rows x 15 columns]

# %%
combined_df.groupby('model')[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity']].mean()
# Out:
#                                       faithfulness  answer_relevancy  \
# model
# 01-ai/yi-34b-chat                         0.453202          0.768168
# 01-ai/yi-6b                               0.523716          0.675393
# 01-ai/yi-6b-chat                          0.300463          0.729144
# google-deepmind/gemma-2b                  0.488684          0.643115
# google-deepmind/gemma-2b-it               0.683333          0.718868
# google-deepmind/gemma-7b                  0.494819          0.505826
# google-deepmind/gemma-7b-it               0.613412          0.560273
# lucataco/qwen1.5-14b                      0.832944          0.657092
# lucataco/qwen1.5-7b                       0.745280          0.772580
# meta/llama-2-13b-chat                     0.625145          0.764821
# meta/llama-2-70b-chat                     0.636885          0.788779
# meta/llama-2-7b-chat                      0.450554          0.692618
# meta/meta-llama-3-70b                     0.570299          0.606678
# meta/meta-llama-3-70b-instruct            0.824787          0.638173
# meta/meta-llama-3-8b                      0.525547          0.742660
# mistralai/mistral-7b-instruct-v0.1        0.611079          0.846696
# mistralai/mistral-7b-instruct-v0.2        0.398690          0.809504
# mistralai/mistral-7b-v0.1                 0.287762          0.497191
# mistralai/mixtral-8x7b-instruct-v0.1      0.772481          0.720865
# nateraw/nous-hermes-2-solar-10.7b         0.728092          0.871356
#
#                                       answer_correctness  answer_similarity
# model
# 01-ai/yi-34b-chat                               0.292709           0.717085
# 01-ai/yi-6b                                     0.255079           0.600136
# 01-ai/yi-6b-chat                                0.219637           0.664692
# google-deepmind/gemma-2b                        0.230968           0.610144
# google-deepmind/gemma-2b-it                     0.349150           0.652813
# google-deepmind/gemma-7b                        0.281832           0.643422
# google-deepmind/gemma-7b-it                     0.215567           0.445517
# lucataco/qwen1.5-14b                            0.351177           0.743944
# lucataco/qwen1.5-7b                             0.342635           0.734182
# meta/llama-2-13b-chat                           0.281698           0.687847
# meta/llama-2-70b-chat                           0.284663           0.727702
# meta/llama-2-7b-chat                            0.266349           0.690632
# meta/meta-llama-3-70b                           0.257083           0.596635
# meta/meta-llama-3-70b-instruct                  0.335544           0.719353
# meta/meta-llama-3-8b                            0.312806           0.643773
# mistralai/mistral-7b-instruct-v0.1              0.356650           0.740715
# mistralai/mistral-7b-instruct-v0.2              0.304772           0.729020
# mistralai/mistral-7b-v0.1                       0.209844           0.575025
# mistralai/mixtral-8x7b-instruct-v0.1            0.340653           0.725717
# nateraw/nous-hermes-2-solar-10.7b               0.369280           0.738520

# %%
grouped_df = combined_df.groupby('model')[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity']].mean()
grouped_df["llm_name"] = grouped_df.index

# Create scatter plot
fig, ax = plt.subplots(figsize=(12, 6))
sc = ax.scatter('faithfulness', 'answer_relevancy', c='answer_similarity', cmap='viridis', data=grouped_df)

# Add text labels with a slight offset
offset = 0.005  # Adjust offset value as needed to prevent overlap
for index, row in grouped_df.iterrows():
    ax.text(row['faithfulness'] + offset, row['answer_relevancy'] + offset, row['llm_name'], fontsize=6)

# Set axis labels
ax.set_xlabel('Faithfulness')
ax.set_ylabel('Answer Relevancy')
ax.set_xlim(right=1.1)  # Extend the x-axis limit for better visibility
ax.set_title('Faithfulness, Answer Relevancy & Answer Similarity')

# Create and label the color bar
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label('Answer Similarity')  # Set color bar label



plt.savefig("Faithfulness-vs-Answer-Relevancy-vs-Answer-Similarity.png")
plt.savefig("Faithfulness-vs-Answer-Relevancy-vs-Answer-Similarity.pdf")
# Show plot
plt.show()

# %%
grouped_df = combined_df.groupby('model')[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity']].mean()
grouped_df["llm_name"] = grouped_df.index

# Create scatter plot
fig, ax = plt.subplots(figsize=(12, 6))
sc = ax.scatter('faithfulness', 'answer_relevancy', c='answer_similarity', cmap='viridis', data=grouped_df)

# Adjust text labels with a slight offset based on index
offset = 0.01  # Adjust offset value as needed to prevent overlap
for i, (index, row) in enumerate(grouped_df.iterrows()):
    # Alternate offsets for better visibility
    if i % 2 == 0:
        ax.text(row['faithfulness'] + offset, row['answer_relevancy'] + offset, row['llm_name'], fontsize=6)
    else:
        ax.text(row['faithfulness'] - offset, row['answer_relevancy'] - offset, row['llm_name'], fontsize=6)

# Set axis labels
ax.set_xlabel('Faithfulness')
ax.set_ylabel('Answer Relevancy')
ax.set_xlim(right=1.1)  # Extend the x-axis limit for better visibility
ax.set_title('Faithfulness, Answer Relevancy & Answer Similarity')

# Create and label the color bar
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label('Answer Similarity')  # Set color bar label

#plt.savefig("/mnt/data/Faithfulness-vs-Answer-Relevancy-vs-Answer-Similarity.png")
#plt.savefig("/mnt/data/Faithfulness-vs-Answer-Relevancy-vs-Answer-Similarity.pdf")
# Show plot
plt.show()

# %%
### Extract Metrics
df_metrics1 = combined_df.groupby('model')[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity', 'BLEUScore', 'ROUGEScore',	'BERTScore']].mean()
df_metrics1
# Out:
#                                       faithfulness  answer_relevancy  \
# model
# 01-ai/yi-34b-chat                         0.453202          0.768168
# 01-ai/yi-6b                               0.523716          0.675393
# 01-ai/yi-6b-chat                          0.300463          0.729144
# google-deepmind/gemma-2b                  0.488684          0.643115
# google-deepmind/gemma-2b-it               0.683333          0.718868
# google-deepmind/gemma-7b                  0.494819          0.505826
# google-deepmind/gemma-7b-it               0.613412          0.560273
# lucataco/qwen1.5-14b                      0.832944          0.657092
# lucataco/qwen1.5-7b                       0.745280          0.772580
# meta/llama-2-13b-chat                     0.625145          0.764821
# meta/llama-2-70b-chat                     0.636885          0.788779
# meta/llama-2-7b-chat                      0.450554          0.692618
# meta/meta-llama-3-70b                     0.570299          0.606678
# meta/meta-llama-3-70b-instruct            0.824787          0.638173
# meta/meta-llama-3-8b                      0.525547          0.742660
# mistralai/mistral-7b-instruct-v0.1        0.611079          0.846696
# mistralai/mistral-7b-instruct-v0.2        0.398690          0.809504
# mistralai/mistral-7b-v0.1                 0.287762          0.497191
# mistralai/mixtral-8x7b-instruct-v0.1      0.772481          0.720865
# nateraw/nous-hermes-2-solar-10.7b         0.728092          0.871356
#
#                                       answer_correctness  answer_similarity  \
# model
# 01-ai/yi-34b-chat                               0.292709           0.717085
# 01-ai/yi-6b                                     0.255079           0.600136
# 01-ai/yi-6b-chat                                0.219637           0.664692
# google-deepmind/gemma-2b                        0.230968           0.610144
# google-deepmind/gemma-2b-it                     0.349150           0.652813
# google-deepmind/gemma-7b                        0.281832           0.643422
# google-deepmind/gemma-7b-it                     0.215567           0.445517
# lucataco/qwen1.5-14b                            0.351177           0.743944
# lucataco/qwen1.5-7b                             0.342635           0.734182
# meta/llama-2-13b-chat                           0.281698           0.687847
# meta/llama-2-70b-chat                           0.284663           0.727702
# meta/llama-2-7b-chat                            0.266349           0.690632
# meta/meta-llama-3-70b                           0.257083           0.596635
# meta/meta-llama-3-70b-instruct                  0.335544           0.719353
# meta/meta-llama-3-8b                            0.312806           0.643773
# mistralai/mistral-7b-instruct-v0.1              0.356650           0.740715
# mistralai/mistral-7b-instruct-v0.2              0.304772           0.729020
# mistralai/mistral-7b-v0.1                       0.209844           0.575025
# mistralai/mixtral-8x7b-instruct-v0.1            0.340653           0.725717
# nateraw/nous-hermes-2-solar-10.7b               0.369280           0.738520
#
#                                       BLEUScore  ROUGEScore  BERTScore
# model
# 01-ai/yi-34b-chat                      0.010215    0.128498   0.842237
# 01-ai/yi-6b                            0.006239    0.179643   0.809785
# 01-ai/yi-6b-chat                       0.003981    0.088050   0.832940
# google-deepmind/gemma-2b               0.010580    0.196961   0.833679
# google-deepmind/gemma-2b-it            0.034342    0.217721   0.872908
# google-deepmind/gemma-7b               0.012604    0.204989   0.842483
# google-deepmind/gemma-7b-it            0.002206    0.025067   0.815060
# lucataco/qwen1.5-14b                   0.036008    0.218652   0.874564
# lucataco/qwen1.5-7b                    0.031571    0.215841   0.872814
# meta/llama-2-13b-chat                  0.015889    0.172563   0.847309
# meta/llama-2-70b-chat                  0.025667    0.203140   0.858527
# meta/llama-2-7b-chat                   0.016475    0.177686   0.848803
# meta/meta-llama-3-70b                  0.007742    0.176944   0.814409
# meta/meta-llama-3-70b-instruct         0.029565    0.206598   0.865319
# meta/meta-llama-3-8b                   0.006804    0.189125   0.816647
# mistralai/mistral-7b-instruct-v0.1     0.032449    0.245859   0.873249
# mistralai/mistral-7b-instruct-v0.2     0.022889    0.215947   0.861542
# mistralai/mistral-7b-v0.1              0.009834    0.151064   0.840959
# mistralai/mixtral-8x7b-instruct-v0.1   0.031268    0.221390   0.865982
# nateraw/nous-hermes-2-solar-10.7b      0.038074    0.230716   0.871635

# %%
df_metrics1["Model"] = df_metrics1.index
df_metrics1[['provider','Model']] = df_metrics1['Model'].str.split('/',expand=True)
#df_metrics1.index = df_metrics1["model"]
df_metrics1
# Out:
#                                       faithfulness  answer_relevancy  \
# model
# 01-ai/yi-34b-chat                         0.453202          0.768168
# 01-ai/yi-6b                               0.523716          0.675393
# 01-ai/yi-6b-chat                          0.300463          0.729144
# google-deepmind/gemma-2b                  0.488684          0.643115
# google-deepmind/gemma-2b-it               0.683333          0.718868
# google-deepmind/gemma-7b                  0.494819          0.505826
# google-deepmind/gemma-7b-it               0.613412          0.560273
# lucataco/qwen1.5-14b                      0.832944          0.657092
# lucataco/qwen1.5-7b                       0.745280          0.772580
# meta/llama-2-13b-chat                     0.625145          0.764821
# meta/llama-2-70b-chat                     0.636885          0.788779
# meta/llama-2-7b-chat                      0.450554          0.692618
# meta/meta-llama-3-70b                     0.570299          0.606678
# meta/meta-llama-3-70b-instruct            0.824787          0.638173
# meta/meta-llama-3-8b                      0.525547          0.742660
# mistralai/mistral-7b-instruct-v0.1        0.611079          0.846696
# mistralai/mistral-7b-instruct-v0.2        0.398690          0.809504
# mistralai/mistral-7b-v0.1                 0.287762          0.497191
# mistralai/mixtral-8x7b-instruct-v0.1      0.772481          0.720865
# nateraw/nous-hermes-2-solar-10.7b         0.728092          0.871356
#
#                                       answer_correctness  answer_similarity  \
# model
# 01-ai/yi-34b-chat                               0.292709           0.717085
# 01-ai/yi-6b                                     0.255079           0.600136
# 01-ai/yi-6b-chat                                0.219637           0.664692
# google-deepmind/gemma-2b                        0.230968           0.610144
# google-deepmind/gemma-2b-it                     0.349150           0.652813
# google-deepmind/gemma-7b                        0.281832           0.643422
# google-deepmind/gemma-7b-it                     0.215567           0.445517
# lucataco/qwen1.5-14b                            0.351177           0.743944
# lucataco/qwen1.5-7b                             0.342635           0.734182
# meta/llama-2-13b-chat                           0.281698           0.687847
# meta/llama-2-70b-chat                           0.284663           0.727702
# meta/llama-2-7b-chat                            0.266349           0.690632
# meta/meta-llama-3-70b                           0.257083           0.596635
# meta/meta-llama-3-70b-instruct                  0.335544           0.719353
# meta/meta-llama-3-8b                            0.312806           0.643773
# mistralai/mistral-7b-instruct-v0.1              0.356650           0.740715
# mistralai/mistral-7b-instruct-v0.2              0.304772           0.729020
# mistralai/mistral-7b-v0.1                       0.209844           0.575025
# mistralai/mixtral-8x7b-instruct-v0.1            0.340653           0.725717
# nateraw/nous-hermes-2-solar-10.7b               0.369280           0.738520
#
#                                       BLEUScore  ROUGEScore  BERTScore  \
# model
# 01-ai/yi-34b-chat                      0.010215    0.128498   0.842237
# 01-ai/yi-6b                            0.006239    0.179643   0.809785
# 01-ai/yi-6b-chat                       0.003981    0.088050   0.832940
# google-deepmind/gemma-2b               0.010580    0.196961   0.833679
# google-deepmind/gemma-2b-it            0.034342    0.217721   0.872908
# google-deepmind/gemma-7b               0.012604    0.204989   0.842483
# google-deepmind/gemma-7b-it            0.002206    0.025067   0.815060
# lucataco/qwen1.5-14b                   0.036008    0.218652   0.874564
# lucataco/qwen1.5-7b                    0.031571    0.215841   0.872814
# meta/llama-2-13b-chat                  0.015889    0.172563   0.847309
# meta/llama-2-70b-chat                  0.025667    0.203140   0.858527
# meta/llama-2-7b-chat                   0.016475    0.177686   0.848803
# meta/meta-llama-3-70b                  0.007742    0.176944   0.814409
# meta/meta-llama-3-70b-instruct         0.029565    0.206598   0.865319
# meta/meta-llama-3-8b                   0.006804    0.189125   0.816647
# mistralai/mistral-7b-instruct-v0.1     0.032449    0.245859   0.873249
# mistralai/mistral-7b-instruct-v0.2     0.022889    0.215947   0.861542
# mistralai/mistral-7b-v0.1              0.009834    0.151064   0.840959
# mistralai/mixtral-8x7b-instruct-v0.1   0.031268    0.221390   0.865982
# nateraw/nous-hermes-2-solar-10.7b      0.038074    0.230716   0.871635
#
#                                                            Model  \
# model
# 01-ai/yi-34b-chat                                    yi-34b-chat
# 01-ai/yi-6b                                                yi-6b
# 01-ai/yi-6b-chat                                      yi-6b-chat
# google-deepmind/gemma-2b                                gemma-2b
# google-deepmind/gemma-2b-it                          gemma-2b-it
# google-deepmind/gemma-7b                                gemma-7b
# google-deepmind/gemma-7b-it                          gemma-7b-it
# lucataco/qwen1.5-14b                                 qwen1.5-14b
# lucataco/qwen1.5-7b                                   qwen1.5-7b
# meta/llama-2-13b-chat                           llama-2-13b-chat
# meta/llama-2-70b-chat                           llama-2-70b-chat
# meta/llama-2-7b-chat                             llama-2-7b-chat
# meta/meta-llama-3-70b                           meta-llama-3-70b
# meta/meta-llama-3-70b-instruct         meta-llama-3-70b-instruct
# meta/meta-llama-3-8b                             meta-llama-3-8b
# mistralai/mistral-7b-instruct-v0.1      mistral-7b-instruct-v0.1
# mistralai/mistral-7b-instruct-v0.2      mistral-7b-instruct-v0.2
# mistralai/mistral-7b-v0.1                        mistral-7b-v0.1
# mistralai/mixtral-8x7b-instruct-v0.1  mixtral-8x7b-instruct-v0.1
# nateraw/nous-hermes-2-solar-10.7b      nous-hermes-2-solar-10.7b
#
#                                              provider
# model
# 01-ai/yi-34b-chat                               01-ai
# 01-ai/yi-6b                                     01-ai
# 01-ai/yi-6b-chat                                01-ai
# google-deepmind/gemma-2b              google-deepmind
# google-deepmind/gemma-2b-it           google-deepmind
# google-deepmind/gemma-7b              google-deepmind
# google-deepmind/gemma-7b-it           google-deepmind
# lucataco/qwen1.5-14b                         lucataco
# lucataco/qwen1.5-7b                          lucataco
# meta/llama-2-13b-chat                            meta
# meta/llama-2-70b-chat                            meta
# meta/llama-2-7b-chat                             meta
# meta/meta-llama-3-70b                            meta
# meta/meta-llama-3-70b-instruct                   meta
# meta/meta-llama-3-8b                             meta
# mistralai/mistral-7b-instruct-v0.1          mistralai
# mistralai/mistral-7b-instruct-v0.2          mistralai
# mistralai/mistral-7b-v0.1                   mistralai
# mistralai/mixtral-8x7b-instruct-v0.1        mistralai
# nateraw/nous-hermes-2-solar-10.7b             nateraw

# %% [markdown]
# ### Load Benchmark Metrics

# %%
df_llm_metrics = pd.read_csv('/home/hamzicd/DS/Paper1-RAGG/impl/LLMs-Overview-Paper-Sheet4.csv')

# %%
df_llm_metrics
# Out:
#                                             Raw model  \
# 0   0: {model: 'meta-llama-3-70b-instruct', runs: ...
# 1       1: {model: 'meta-llama-3-8b', runs: 48900000}
# 2   2: {model: 'meta-llama-3-8b-instruct', runs: 3...
# 3   3: {model: 'mixtral-8x7b-instruct-v0.1', runs:...
# 4        4: {model: 'llama-2-7b-chat', runs: 8400000}
# 5       5: {model: 'llama-2-70b-chat', runs: 7400000}
# 6       6: {model: 'llama-2-13b-chat', runs: 4400000}
# 7   7: {model: 'mistral-7b-instruct-v0.2', runs: 2...
# 8        8: {model: 'mistral-7b-v0.1', runs: 1700000}
# 9   9: {model: 'mistral-7b-instruct-v0.1', runs: 9...
# 10          10: {model: 'dolly-v2-12b', runs: 453100}
# 11      11: {model: 'meta-llama-3-70b', runs: 339400}
# 12           12: {model: 'yi-34b-chat', runs: 253900}
# 13            13: {model: 'vicuna-13b', runs: 251200}
# 14                 14: {model: 'yi-6b', runs: 158100}
# 15            15: {model: 'flan-t5-xl', runs: 136600}
# 16  16: {model: 'stablelm-tuned-alpha-7b', runs: 1...
# 17               17: {model: 'llama-7b', runs: 98500}
# 18            18: {model: 'gemma-2b-it', runs: 82300}
# 19  19: {model: 'gemma-7b-it', runs: 64900.0000000...
# 20  20: {model: 'nous-hermes-2-solar-10.7b', runs:...
# 21  21: {model: 'oasst-sft-1-pythia-12b', runs: 32...
# 22  22: {model: 'nous-hermes-2-yi-34b-gguf', runs:...
# 23                23: {model: 'gpt-j-6b', runs: 8400}
# 24  24: {model: 'nous-hermes-llama2-awq', runs: 7200}
# 25                25: {model: 'gemma-7b', runs: 6800}
# 26              26: {model: 'yi-6b-chat', runs: 4000}
# 27             27: {model: 'qwen1.5-72b', runs: 3800}
# 28                   28: {model: 'phi-2', runs: 2700}
# 29       29: {model: 'replit-code-v1-3b', runs: 1900}
# 30                 30: {model: 'gemma-2b', runs: 588}
# 31              31: {model: 'qwen1.5-14b', runs: 281}
# 32               32: {model: 'mamba-2.8b', runs: 216}
# 33          33: {model: 'phixtral-2x2_​8', runs: 197}
# 34               34: {model: 'qwen1.5-7b', runs: 109}
# 35               35: {model: 'mamba-130m', runs: 101}
# 36                   36: {model: 'olmo-7b', runs: 74}
# 37                37: {model: 'mamba-1.4b', runs: 45}
# 38         38: {model: 'mamba-2.8b-slimpj', runs: 45}
# 39                39: {model: 'mamba-370m', runs: 33}
# 40                40: {model: 'mamba-790m', runs: 27}
#
#                          Model  Unnamed: 2  Average ⬆️  IFEval    BBH  \
# 0    meta-llama-3-70b-instruct         NaN       36.18   80.99  50.19
# 1              meta-llama-3-8b         NaN       13.41   14.55  24.50
# 2     meta-llama-3-8b-instruct         NaN       23.91   74.08  28.24
# 3   mixtral-8x7b-instruct-v0.1         NaN       24.35   53.95  34.02
# 4              llama-2-7b-chat         NaN        9.40   39.65   4.49
# 5             llama-2-70b-chat         NaN       12.73   49.58   4.61
# 6             llama-2-13b-chat         NaN       11.00   39.85   7.16
# 7     mistral-7b-instruct-v0.2         NaN       18.44   54.96  22.91
# 8              mistral-7b-v0.1         NaN       14.50   23.86  22.02
# 9     mistral-7b-instruct-v0.1         NaN       13.57   45.02  13.79
# 10                dolly-v2-12b         NaN        6.38   23.55   6.38
# 11            meta-llama-3-70b         NaN       26.37   16.03  48.71
# 12                 yi-34b-chat         NaN       23.90   46.99  37.62
# 13                  vicuna-13b         NaN         NaN     NaN    NaN
# 14                       yi-6b         NaN       13.60   28.93  19.41
# 15                  flan-t5-xl         NaN         NaN     NaN    NaN
# 16     stablelm-tuned-alpha-7b         NaN         NaN     NaN    NaN
# 17                    llama-7b         NaN         NaN     NaN    NaN
# 18                 gemma-2b-it         NaN        7.22   26.90   5.21
# 19                 gemma-7b-it         NaN       12.84   38.68  11.94
# 20   nous-hermes-2-solar-10.7b         NaN       23.32   52.79  34.99
# 21      oasst-sft-1-pythia-12b         NaN        3.67   10.55   4.78
# 22   nous-hermes-2-yi-34b-gguf         NaN         NaN     NaN    NaN
# 23                    gpt-j-6b         NaN        6.55   25.22   4.91
# 24      nous-hermes-llama2-awq         NaN         NaN     NaN    NaN
# 25                    gemma-7b         NaN       15.28   26.59  21.12
# 26                  yi-6b-chat         NaN       14.00   33.95  17.00
# 27                 qwen1.5-72b         NaN         NaN     NaN    NaN
# 28                       phi-2         NaN       15.45   27.39  28.04
# 29           replit-code-v1-3b         NaN         NaN     NaN    NaN
# 30                    gemma-2b         NaN        7.27   20.38   8.25
# 31                 qwen1.5-14b         NaN       20.22   29.05  30.06
# 32                  mamba-2.8b         NaN         NaN     NaN    NaN
# 33             phixtral-2x2_​8         NaN         NaN     NaN    NaN
# 34                  qwen1.5-7b         NaN       15.22   26.84  23.08
# 35                  mamba-130m         NaN         NaN     NaN    NaN
# 36                     olmo-7b         NaN         NaN     NaN    NaN
# 37                  mamba-1.4b         NaN         NaN     NaN    NaN
# 38           mamba-2.8b-slimpj         NaN         NaN     NaN    NaN
# 39                  mamba-370m         NaN         NaN     NaN    NaN
# 40                  mamba-790m         NaN         NaN     NaN    NaN
#
#     MATH Lvl 5   GPQA   MUSR  MMLU-PRO  \
# 0        23.34   4.92  10.92     46.74
# 1         3.25   7.38   6.24     24.55
# 2         8.69   1.23   1.60     29.60
# 3         9.06   7.61  12.11     29.36
# 4         0.68   0.56   3.48      7.52
# 5         0.91   1.90   3.48     15.92
# 6         0.60   0.00   8.16     10.26
# 7         2.64   3.47   7.61     19.08
# 8         2.49   5.59  10.68     22.36
# 9         1.51   0.00   5.77     15.34
# 10        1.44   0.00   5.50      1.43
# 11       16.54  19.69  16.01     41.21
# 12        4.31  11.74   8.36     34.37
# 13         NaN    NaN    NaN       NaN
# 14        1.51   2.57   7.04     22.12
# 15         NaN    NaN    NaN       NaN
# 16         NaN    NaN    NaN       NaN
# 17         NaN    NaN    NaN       NaN
# 18        0.45   3.80   3.03      3.92
# 19        1.59   4.59  12.53      7.72
# 20        5.21   5.82  13.83     27.31
# 21        1.44   1.01   2.99      1.25
# 22         NaN    NaN    NaN       NaN
# 23        1.21   0.00   5.25      2.68
# 24         NaN    NaN    NaN       NaN
# 25        6.42   4.92  10.98     21.64
# 26        0.68   5.93   3.57     22.90
# 27         NaN    NaN    NaN       NaN
# 28        2.42   2.91  13.84     18.09
# 29         NaN    NaN    NaN       NaN
# 30        2.72   0.67   7.56      4.06
# 31       16.47   5.93  10.46     29.37
# 32         NaN    NaN    NaN       NaN
# 33         NaN    NaN    NaN       NaN
# 34        4.46   6.49   9.16     21.29
# 35         NaN    NaN    NaN       NaN
# 36         NaN    NaN    NaN       NaN
# 37         NaN    NaN    NaN       NaN
# 38         NaN    NaN    NaN       NaN
# 39         NaN    NaN    NaN       NaN
# 40         NaN    NaN    NaN       NaN
#
#                                         Type
# 0        💬 chat models (RLHF, DPO, IFT, ...)
# 1                               🟢 pretrained
# 2        💬 chat models (RLHF, DPO, IFT, ...)
# 3        💬 chat models (RLHF, DPO, IFT, ...)
# 4        💬 chat models (RLHF, DPO, IFT, ...)
# 5        💬 chat models (RLHF, DPO, IFT, ...)
# 6        💬 chat models (RLHF, DPO, IFT, ...)
# 7        💬 chat models (RLHF, DPO, IFT, ...)
# 8                               🟢 pretrained
# 9        💬 chat models (RLHF, DPO, IFT, ...)
# 10  🔶 fine-tuned on domain-specific datasets
# 11                              🟢 pretrained
# 12       💬 chat models (RLHF, DPO, IFT, ...)
# 13                                       NaN
# 14                              🟢 pretrained
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18       💬 chat models (RLHF, DPO, IFT, ...)
# 19       💬 chat models (RLHF, DPO, IFT, ...)
# 20       💬 chat models (RLHF, DPO, IFT, ...)
# 21  🔶 fine-tuned on domain-specific datasets
# 22                                       NaN
# 23                              🟢 pretrained
# 24                                       NaN
# 25                              🟢 pretrained
# 26       💬 chat models (RLHF, DPO, IFT, ...)
# 27                                       NaN
# 28                              🟢 pretrained
# 29                                       NaN
# 30                              🟢 pretrained
# 31                              🟢 pretrained
# 32                                       NaN
# 33                                       NaN
# 34                              🟢 pretrained
# 35                                       NaN
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39                                       NaN
# 40                                       NaN

# %%
df_metrics_combined = pd.merge(df_llm_metrics, df_metrics1, on='Model')#.corr()
df_metrics_combined.index = df_metrics_combined.Model
df_metrics_combined.drop(columns=['Raw model', 'Unnamed: 2', 'provider', "Model"], inplace=True)

# %%
df_metrics_combined
# Out:
#                             Average ⬆️  IFEval    BBH  MATH Lvl 5   GPQA  \
# Model
# meta-llama-3-70b-instruct        36.18   80.99  50.19       23.34   4.92
# meta-llama-3-8b                  13.41   14.55  24.50        3.25   7.38
# mixtral-8x7b-instruct-v0.1       24.35   53.95  34.02        9.06   7.61
# llama-2-7b-chat                   9.40   39.65   4.49        0.68   0.56
# llama-2-70b-chat                 12.73   49.58   4.61        0.91   1.90
# llama-2-13b-chat                 11.00   39.85   7.16        0.60   0.00
# mistral-7b-instruct-v0.2         18.44   54.96  22.91        2.64   3.47
# mistral-7b-v0.1                  14.50   23.86  22.02        2.49   5.59
# mistral-7b-instruct-v0.1         13.57   45.02  13.79        1.51   0.00
# meta-llama-3-70b                 26.37   16.03  48.71       16.54  19.69
# yi-34b-chat                      23.90   46.99  37.62        4.31  11.74
# yi-6b                            13.60   28.93  19.41        1.51   2.57
# gemma-2b-it                       7.22   26.90   5.21        0.45   3.80
# gemma-7b-it                      12.84   38.68  11.94        1.59   4.59
# nous-hermes-2-solar-10.7b        23.32   52.79  34.99        5.21   5.82
# gemma-7b                         15.28   26.59  21.12        6.42   4.92
# yi-6b-chat                       14.00   33.95  17.00        0.68   5.93
# gemma-2b                          7.27   20.38   8.25        2.72   0.67
# qwen1.5-14b                      20.22   29.05  30.06       16.47   5.93
# qwen1.5-7b                       15.22   26.84  23.08        4.46   6.49
#
#                              MUSR  MMLU-PRO  \
# Model
# meta-llama-3-70b-instruct   10.92     46.74
# meta-llama-3-8b              6.24     24.55
# mixtral-8x7b-instruct-v0.1  12.11     29.36
# llama-2-7b-chat              3.48      7.52
# llama-2-70b-chat             3.48     15.92
# llama-2-13b-chat             8.16     10.26
# mistral-7b-instruct-v0.2     7.61     19.08
# mistral-7b-v0.1             10.68     22.36
# mistral-7b-instruct-v0.1     5.77     15.34
# meta-llama-3-70b            16.01     41.21
# yi-34b-chat                  8.36     34.37
# yi-6b                        7.04     22.12
# gemma-2b-it                  3.03      3.92
# gemma-7b-it                 12.53      7.72
# nous-hermes-2-solar-10.7b   13.83     27.31
# gemma-7b                    10.98     21.64
# yi-6b-chat                   3.57     22.90
# gemma-2b                     7.56      4.06
# qwen1.5-14b                 10.46     29.37
# qwen1.5-7b                   9.16     21.29
#
#                                                            Type  faithfulness  \
# Model
# meta-llama-3-70b-instruct   💬 chat models (RLHF, DPO, IFT, ...)      0.824787
# meta-llama-3-8b                                    🟢 pretrained      0.525547
# mixtral-8x7b-instruct-v0.1  💬 chat models (RLHF, DPO, IFT, ...)      0.772481
# llama-2-7b-chat             💬 chat models (RLHF, DPO, IFT, ...)      0.450554
# llama-2-70b-chat            💬 chat models (RLHF, DPO, IFT, ...)      0.636885
# llama-2-13b-chat            💬 chat models (RLHF, DPO, IFT, ...)      0.625145
# mistral-7b-instruct-v0.2    💬 chat models (RLHF, DPO, IFT, ...)      0.398690
# mistral-7b-v0.1                                    🟢 pretrained      0.287762
# mistral-7b-instruct-v0.1    💬 chat models (RLHF, DPO, IFT, ...)      0.611079
# meta-llama-3-70b                                   🟢 pretrained      0.570299
# yi-34b-chat                 💬 chat models (RLHF, DPO, IFT, ...)      0.453202
# yi-6b                                              🟢 pretrained      0.523716
# gemma-2b-it                 💬 chat models (RLHF, DPO, IFT, ...)      0.683333
# gemma-7b-it                 💬 chat models (RLHF, DPO, IFT, ...)      0.613412
# nous-hermes-2-solar-10.7b   💬 chat models (RLHF, DPO, IFT, ...)      0.728092
# gemma-7b                                           🟢 pretrained      0.494819
# yi-6b-chat                  💬 chat models (RLHF, DPO, IFT, ...)      0.300463
# gemma-2b                                           🟢 pretrained      0.488684
# qwen1.5-14b                                        🟢 pretrained      0.832944
# qwen1.5-7b                                         🟢 pretrained      0.745280
#
#                             answer_relevancy  answer_correctness  \
# Model
# meta-llama-3-70b-instruct           0.638173            0.335544
# meta-llama-3-8b                     0.742660            0.312806
# mixtral-8x7b-instruct-v0.1          0.720865            0.340653
# llama-2-7b-chat                     0.692618            0.266349
# llama-2-70b-chat                    0.788779            0.284663
# llama-2-13b-chat                    0.764821            0.281698
# mistral-7b-instruct-v0.2            0.809504            0.304772
# mistral-7b-v0.1                     0.497191            0.209844
# mistral-7b-instruct-v0.1            0.846696            0.356650
# meta-llama-3-70b                    0.606678            0.257083
# yi-34b-chat                         0.768168            0.292709
# yi-6b                               0.675393            0.255079
# gemma-2b-it                         0.718868            0.349150
# gemma-7b-it                         0.560273            0.215567
# nous-hermes-2-solar-10.7b           0.871356            0.369280
# gemma-7b                            0.505826            0.281832
# yi-6b-chat                          0.729144            0.219637
# gemma-2b                            0.643115            0.230968
# qwen1.5-14b                         0.657092            0.351177
# qwen1.5-7b                          0.772580            0.342635
#
#                             answer_similarity  BLEUScore  ROUGEScore  \
# Model
# meta-llama-3-70b-instruct            0.719353   0.029565    0.206598
# meta-llama-3-8b                      0.643773   0.006804    0.189125
# mixtral-8x7b-instruct-v0.1           0.725717   0.031268    0.221390
# llama-2-7b-chat                      0.690632   0.016475    0.177686
# llama-2-70b-chat                     0.727702   0.025667    0.203140
# llama-2-13b-chat                     0.687847   0.015889    0.172563
# mistral-7b-instruct-v0.2             0.729020   0.022889    0.215947
# mistral-7b-v0.1                      0.575025   0.009834    0.151064
# mistral-7b-instruct-v0.1             0.740715   0.032449    0.245859
# meta-llama-3-70b                     0.596635   0.007742    0.176944
# yi-34b-chat                          0.717085   0.010215    0.128498
# yi-6b                                0.600136   0.006239    0.179643
# gemma-2b-it                          0.652813   0.034342    0.217721
# gemma-7b-it                          0.445517   0.002206    0.025067
# nous-hermes-2-solar-10.7b            0.738520   0.038074    0.230716
# gemma-7b                             0.643422   0.012604    0.204989
# yi-6b-chat                           0.664692   0.003981    0.088050
# gemma-2b                             0.610144   0.010580    0.196961
# qwen1.5-14b                          0.743944   0.036008    0.218652
# qwen1.5-7b                           0.734182   0.031571    0.215841
#
#                             BERTScore
# Model
# meta-llama-3-70b-instruct    0.865319
# meta-llama-3-8b              0.816647
# mixtral-8x7b-instruct-v0.1   0.865982
# llama-2-7b-chat              0.848803
# llama-2-70b-chat             0.858527
# llama-2-13b-chat             0.847309
# mistral-7b-instruct-v0.2     0.861542
# mistral-7b-v0.1              0.840959
# mistral-7b-instruct-v0.1     0.873249
# meta-llama-3-70b             0.814409
# yi-34b-chat                  0.842237
# yi-6b                        0.809785
# gemma-2b-it                  0.872908
# gemma-7b-it                  0.815060
# nous-hermes-2-solar-10.7b    0.871635
# gemma-7b                     0.842483
# yi-6b-chat                   0.832940
# gemma-2b                     0.833679
# qwen1.5-14b                  0.874564
# qwen1.5-7b                   0.872814

# %%
df_metrics_combined_corr = pd.get_dummies(df_metrics_combined).corr()
df_metrics_combined_corr
# Out:
#                                           Average ⬆️    IFEval       BBH  \
# Average ⬆️                                  1.000000  0.571837  0.938072
# IFEval                                      0.571837  1.000000  0.277908
# BBH                                         0.938072  0.277908  1.000000
# MATH Lvl 5                                  0.835369  0.292967  0.814559
# GPQA                                        0.570597 -0.219450  0.745262
# MUSR                                        0.627796  0.049252  0.706692
# MMLU-PRO                                    0.926703  0.311910  0.950548
# faithfulness                                0.392836  0.346380  0.286490
# answer_relevancy                           -0.002851  0.355799 -0.087167
# answer_correctness                          0.343403  0.370714  0.283516
# answer_similarity                           0.307466  0.467593  0.188777
# BLEUScore                                   0.252535  0.448737  0.120456
# ROUGEScore                                  0.140814  0.138571  0.127753
# BERTScore                                   0.177024  0.492262  0.016169
# Type_💬 chat models (RLHF, DPO, IFT, ...)    0.105591  0.735111 -0.156744
# Type_🟢 pretrained                          -0.105591 -0.735111  0.156744
#
#                                           MATH Lvl 5      GPQA      MUSR  \
# Average ⬆️                                  0.835369  0.570597  0.627796
# IFEval                                      0.292967 -0.219450  0.049252
# BBH                                         0.814559  0.745262  0.706692
# MATH Lvl 5                                  1.000000  0.501910  0.598733
# GPQA                                        0.501910  1.000000  0.584571
# MUSR                                        0.598733  0.584571  1.000000
# MMLU-PRO                                    0.795662  0.691029  0.552640
# faithfulness                                0.535365  0.016798  0.310775
# answer_relevancy                           -0.272236 -0.196460 -0.355669
# answer_correctness                          0.311942 -0.022307  0.043971
# answer_similarity                           0.194620 -0.119825 -0.220574
# BLEUScore                                   0.275739 -0.195916  0.012341
# ROUGEScore                                  0.239422 -0.158882 -0.044823
# BERTScore                                   0.162695 -0.285343 -0.111390
# Type_💬 chat models (RLHF, DPO, IFT, ...)   -0.196204 -0.274334 -0.277690
# Type_🟢 pretrained                           0.196204  0.274334  0.277690
#
#                                           MMLU-PRO  faithfulness  \
# Average ⬆️                                0.926703      0.392836
# IFEval                                    0.311910      0.346380
# BBH                                       0.950548      0.286490
# MATH Lvl 5                                0.795662      0.535365
# GPQA                                      0.691029      0.016798
# MUSR                                      0.552640      0.310775
# MMLU-PRO                                  1.000000      0.238989
# faithfulness                              0.238989      1.000000
# answer_relevancy                         -0.063908      0.224994
# answer_correctness                        0.246819      0.729252
# answer_similarity                         0.277145      0.361997
# BLEUScore                                 0.091879      0.718981
# ROUGEScore                                0.123090      0.442098
# BERTScore                                 0.010592      0.529170
# Type_💬 chat models (RLHF, DPO, IFT, ...) -0.142376      0.104054
# Type_🟢 pretrained                         0.142376     -0.104054
#
#                                           answer_relevancy  \
# Average ⬆️                                       -0.002851
# IFEval                                            0.355799
# BBH                                              -0.087167
# MATH Lvl 5                                       -0.272236
# GPQA                                             -0.196460
# MUSR                                             -0.355669
# MMLU-PRO                                         -0.063908
# faithfulness                                      0.224994
# answer_relevancy                                  1.000000
# answer_correctness                                0.589486
# answer_similarity                                 0.691878
# BLEUScore                                         0.497546
# ROUGEScore                                        0.395707
# BERTScore                                         0.467809
# Type_💬 chat models (RLHF, DPO, IFT, ...)          0.507516
# Type_🟢 pretrained                                -0.507516
#
#                                           answer_correctness  \
# Average ⬆️                                          0.343403
# IFEval                                              0.370714
# BBH                                                 0.283516
# MATH Lvl 5                                          0.311942
# GPQA                                               -0.022307
# MUSR                                                0.043971
# MMLU-PRO                                            0.246819
# faithfulness                                        0.729252
# answer_relevancy                                    0.589486
# answer_correctness                                  1.000000
# answer_similarity                                   0.746305
# BLEUScore                                           0.880327
# ROUGEScore                                          0.745411
# BERTScore                                           0.770010
# Type_💬 chat models (RLHF, DPO, IFT, ...)            0.209121
# Type_🟢 pretrained                                  -0.209121
#
#                                           answer_similarity  BLEUScore  \
# Average ⬆️                                         0.307466   0.252535
# IFEval                                             0.467593   0.448737
# BBH                                                0.188777   0.120456
# MATH Lvl 5                                         0.194620   0.275739
# GPQA                                              -0.119825  -0.195916
# MUSR                                              -0.220574   0.012341
# MMLU-PRO                                           0.277145   0.091879
# faithfulness                                       0.361997   0.718981
# answer_relevancy                                   0.691878   0.497546
# answer_correctness                                 0.746305   0.880327
# answer_similarity                                  1.000000   0.732502
# BLEUScore                                          0.732502   1.000000
# ROUGEScore                                         0.707785   0.743931
# BERTScore                                          0.773449   0.937971
# Type_💬 chat models (RLHF, DPO, IFT, ...)           0.286114   0.280143
# Type_🟢 pretrained                                 -0.286114  -0.280143
#
#                                           ROUGEScore  BERTScore  \
# Average ⬆️                                  0.140814   0.177024
# IFEval                                      0.138571   0.492262
# BBH                                         0.127753   0.016169
# MATH Lvl 5                                  0.239422   0.162695
# GPQA                                       -0.158882  -0.285343
# MUSR                                       -0.044823  -0.111390
# MMLU-PRO                                    0.123090   0.010592
# faithfulness                                0.442098   0.529170
# answer_relevancy                            0.395707   0.467809
# answer_correctness                          0.745411   0.770010
# answer_similarity                           0.707785   0.773449
# BLEUScore                                   0.743931   0.937971
# ROUGEScore                                  1.000000   0.641272
# BERTScore                                   0.641272   1.000000
# Type_💬 chat models (RLHF, DPO, IFT, ...)   -0.133184   0.374747
# Type_🟢 pretrained                           0.133184  -0.374747
#
#                                           Type_💬 chat models (RLHF, DPO, IFT, ...)  \
# Average ⬆️                                                                0.105591
# IFEval                                                                    0.735111
# BBH                                                                      -0.156744
# MATH Lvl 5                                                               -0.196204
# GPQA                                                                     -0.274334
# MUSR                                                                     -0.277690
# MMLU-PRO                                                                 -0.142376
# faithfulness                                                              0.104054
# answer_relevancy                                                          0.507516
# answer_correctness                                                        0.209121
# answer_similarity                                                         0.286114
# BLEUScore                                                                 0.280143
# ROUGEScore                                                               -0.133184
# BERTScore                                                                 0.374747
# Type_💬 chat models (RLHF, DPO, IFT, ...)                                  1.000000
# Type_🟢 pretrained                                                        -1.000000
#
#                                           Type_🟢 pretrained
# Average ⬆️                                        -0.105591
# IFEval                                            -0.735111
# BBH                                                0.156744
# MATH Lvl 5                                         0.196204
# GPQA                                               0.274334
# MUSR                                               0.277690
# MMLU-PRO                                           0.142376
# faithfulness                                      -0.104054
# answer_relevancy                                  -0.507516
# answer_correctness                                -0.209121
# answer_similarity                                 -0.286114
# BLEUScore                                         -0.280143
# ROUGEScore                                         0.133184
# BERTScore                                         -0.374747
# Type_💬 chat models (RLHF, DPO, IFT, ...)          -1.000000
# Type_🟢 pretrained                                  1.000000

# %%
# Plotting the correlation matrix using seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(df_metrics_combined_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Metrics')
plt.show()
# Out:
# /home/hamzicd/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 128172 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/hamzicd/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 128994 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/hamzicd/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 128172 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/hamzicd/.local/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 128994 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
grouped_df = combined_df.groupby('model')[['faithfulness', 'answer_relevancy', 'answer_correctness', 'answer_similarity', 'BLEUScore', 'BERTScore']].mean()
grouped_df["llm_name"] = grouped_df.index

# Create scatter plot
fig, ax = plt.subplots(figsize=(12, 6))
sc = ax.scatter('faithfulness', 'BLEUScore', c='BERTScore', cmap='viridis', data=grouped_df)

# Add text labels with a slight offset
offset = 0.005  # Adjust offset value as needed to prevent overlap
for index, row in grouped_df.iterrows():
    ax.text(row['faithfulness'] + offset, row['BLEUScore'] + offset, row['llm_name'], fontsize=6)

# Set axis labels
ax.set_xlabel('Faithfulness')
ax.set_ylabel('BLEUScore')
ax.set_xlim(right=1.1)  # Extend the x-axis limit for better visibility
ax.set_title('Faithfulness, BLEUScore & BERTScore')

# Create and label the color bar
cbar = fig.colorbar(sc, ax=ax)
cbar.set_label('BERTScore')  # Set color bar label



#plt.savefig("Faithfulness-vs-Answer-Relevancy-vs-Answer-Similarity.png")
#plt.savefig("Faithfulness-vs-Answer-Relevancy-vs-Answer-Similarity.pdf")
# Show plot
plt.show()

# %%
grouped_df
# Out:
#                                       faithfulness  answer_relevancy  \
# model
# 01-ai/yi-34b-chat                         0.453202          0.768168
# 01-ai/yi-6b                               0.523716          0.675393
# 01-ai/yi-6b-chat                          0.300463          0.729144
# google-deepmind/gemma-2b                  0.488684          0.643115
# google-deepmind/gemma-2b-it               0.683333          0.718868
# google-deepmind/gemma-7b                  0.494819          0.505826
# google-deepmind/gemma-7b-it               0.613412          0.560273
# lucataco/qwen1.5-14b                      0.832944          0.657092
# lucataco/qwen1.5-7b                       0.745280          0.772580
# meta/llama-2-13b-chat                     0.625145          0.764821
# meta/llama-2-70b-chat                     0.636885          0.788779
# meta/llama-2-7b-chat                      0.450554          0.692618
# meta/meta-llama-3-70b                     0.570299          0.606678
# meta/meta-llama-3-70b-instruct            0.824787          0.638173
# meta/meta-llama-3-8b                      0.525547          0.742660
# mistralai/mistral-7b-instruct-v0.1        0.611079          0.846696
# mistralai/mistral-7b-instruct-v0.2        0.398690          0.809504
# mistralai/mistral-7b-v0.1                 0.287762          0.497191
# mistralai/mixtral-8x7b-instruct-v0.1      0.772481          0.720865
# nateraw/nous-hermes-2-solar-10.7b         0.728092          0.871356
#
#                                       answer_correctness  answer_similarity  \
# model
# 01-ai/yi-34b-chat                               0.292709           0.717085
# 01-ai/yi-6b                                     0.255079           0.600136
# 01-ai/yi-6b-chat                                0.219637           0.664692
# google-deepmind/gemma-2b                        0.230968           0.610144
# google-deepmind/gemma-2b-it                     0.349150           0.652813
# google-deepmind/gemma-7b                        0.281832           0.643422
# google-deepmind/gemma-7b-it                     0.215567           0.445517
# lucataco/qwen1.5-14b                            0.351177           0.743944
# lucataco/qwen1.5-7b                             0.342635           0.734182
# meta/llama-2-13b-chat                           0.281698           0.687847
# meta/llama-2-70b-chat                           0.284663           0.727702
# meta/llama-2-7b-chat                            0.266349           0.690632
# meta/meta-llama-3-70b                           0.257083           0.596635
# meta/meta-llama-3-70b-instruct                  0.335544           0.719353
# meta/meta-llama-3-8b                            0.312806           0.643773
# mistralai/mistral-7b-instruct-v0.1              0.356650           0.740715
# mistralai/mistral-7b-instruct-v0.2              0.304772           0.729020
# mistralai/mistral-7b-v0.1                       0.209844           0.575025
# mistralai/mixtral-8x7b-instruct-v0.1            0.340653           0.725717
# nateraw/nous-hermes-2-solar-10.7b               0.369280           0.738520
#
#                                       BLEUScore  BERTScore  \
# model
# 01-ai/yi-34b-chat                      0.010215   0.842237
# 01-ai/yi-6b                            0.006239   0.809785
# 01-ai/yi-6b-chat                       0.003981   0.832940
# google-deepmind/gemma-2b               0.010580   0.833679
# google-deepmind/gemma-2b-it            0.034342   0.872908
# google-deepmind/gemma-7b               0.012604   0.842483
# google-deepmind/gemma-7b-it            0.002206   0.815060
# lucataco/qwen1.5-14b                   0.036008   0.874564
# lucataco/qwen1.5-7b                    0.031571   0.872814
# meta/llama-2-13b-chat                  0.015889   0.847309
# meta/llama-2-70b-chat                  0.025667   0.858527
# meta/llama-2-7b-chat                   0.016475   0.848803
# meta/meta-llama-3-70b                  0.007742   0.814409
# meta/meta-llama-3-70b-instruct         0.029565   0.865319
# meta/meta-llama-3-8b                   0.006804   0.816647
# mistralai/mistral-7b-instruct-v0.1     0.032449   0.873249
# mistralai/mistral-7b-instruct-v0.2     0.022889   0.861542
# mistralai/mistral-7b-v0.1              0.009834   0.840959
# mistralai/mixtral-8x7b-instruct-v0.1   0.031268   0.865982
# nateraw/nous-hermes-2-solar-10.7b      0.038074   0.871635
#
#                                                                   llm_name
# model
# 01-ai/yi-34b-chat                                        01-ai/yi-34b-chat
# 01-ai/yi-6b                                                    01-ai/yi-6b
# 01-ai/yi-6b-chat                                          01-ai/yi-6b-chat
# google-deepmind/gemma-2b                          google-deepmind/gemma-2b
# google-deepmind/gemma-2b-it                    google-deepmind/gemma-2b-it
# google-deepmind/gemma-7b                          google-deepmind/gemma-7b
# google-deepmind/gemma-7b-it                    google-deepmind/gemma-7b-it
# lucataco/qwen1.5-14b                                  lucataco/qwen1.5-14b
# lucataco/qwen1.5-7b                                    lucataco/qwen1.5-7b
# meta/llama-2-13b-chat                                meta/llama-2-13b-chat
# meta/llama-2-70b-chat                                meta/llama-2-70b-chat
# meta/llama-2-7b-chat                                  meta/llama-2-7b-chat
# meta/meta-llama-3-70b                                meta/meta-llama-3-70b
# meta/meta-llama-3-70b-instruct              meta/meta-llama-3-70b-instruct
# meta/meta-llama-3-8b                                  meta/meta-llama-3-8b
# mistralai/mistral-7b-instruct-v0.1      mistralai/mistral-7b-instruct-v0.1
# mistralai/mistral-7b-instruct-v0.2      mistralai/mistral-7b-instruct-v0.2
# mistralai/mistral-7b-v0.1                        mistralai/mistral-7b-v0.1
# mistralai/mixtral-8x7b-instruct-v0.1  mistralai/mixtral-8x7b-instruct-v0.1
# nateraw/nous-hermes-2-solar-10.7b        nateraw/nous-hermes-2-solar-10.7b

# %%
df_metrics_combined.head()
# Out:
#                             Average ⬆️  IFEval    BBH  MATH Lvl 5  GPQA  \
# Model
# meta-llama-3-70b-instruct        36.18   80.99  50.19       23.34  4.92
# meta-llama-3-8b                  13.41   14.55  24.50        3.25  7.38
# mixtral-8x7b-instruct-v0.1       24.35   53.95  34.02        9.06  7.61
# llama-2-7b-chat                   9.40   39.65   4.49        0.68  0.56
# llama-2-70b-chat                 12.73   49.58   4.61        0.91  1.90
#
#                              MUSR  MMLU-PRO  \
# Model
# meta-llama-3-70b-instruct   10.92     46.74
# meta-llama-3-8b              6.24     24.55
# mixtral-8x7b-instruct-v0.1  12.11     29.36
# llama-2-7b-chat              3.48      7.52
# llama-2-70b-chat             3.48     15.92
#
#                                                            Type  faithfulness  \
# Model
# meta-llama-3-70b-instruct   💬 chat models (RLHF, DPO, IFT, ...)      0.824787
# meta-llama-3-8b                                    🟢 pretrained      0.525547
# mixtral-8x7b-instruct-v0.1  💬 chat models (RLHF, DPO, IFT, ...)      0.772481
# llama-2-7b-chat             💬 chat models (RLHF, DPO, IFT, ...)      0.450554
# llama-2-70b-chat            💬 chat models (RLHF, DPO, IFT, ...)      0.636885
#
#                             answer_relevancy  answer_correctness  \
# Model
# meta-llama-3-70b-instruct           0.638173            0.335544
# meta-llama-3-8b                     0.742660            0.312806
# mixtral-8x7b-instruct-v0.1          0.720865            0.340653
# llama-2-7b-chat                     0.692618            0.266349
# llama-2-70b-chat                    0.788779            0.284663
#
#                             answer_similarity  BLEUScore  ROUGEScore  \
# Model
# meta-llama-3-70b-instruct            0.719353   0.029565    0.206598
# meta-llama-3-8b                      0.643773   0.006804    0.189125
# mixtral-8x7b-instruct-v0.1           0.725717   0.031268    0.221390
# llama-2-7b-chat                      0.690632   0.016475    0.177686
# llama-2-70b-chat                     0.727702   0.025667    0.203140
#
#                             BERTScore
# Model
# meta-llama-3-70b-instruct    0.865319
# meta-llama-3-8b              0.816647
# mixtral-8x7b-instruct-v0.1   0.865982
# llama-2-7b-chat              0.848803
# llama-2-70b-chat             0.858527

# %%
X = df_metrics_combined[['IFEval', 'BBH', 'MATH Lvl 5', 'GPQA', 'MUSR', 'MMLU-PRO']]
# 'answer_relevancy', 'answer_correctness', 'answer_similarity', 'BLEUScore','ROUGEScore', 'BERTScore'
#y = df_metrics_combined['faithfulness']
y = df_metrics_combined['faithfulness']

# %%
import statsmodels.api as sm
# Add a constant to the independent variables
X = sm.add_constant(X)

# Fit the linear regression model
model = sm.OLS(y, X).fit()

# Print the summary of the regression model
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           faithfulness   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     1.763
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.184
# Time:                        09:42:35   Log-Likelihood:                 14.886
# No. Observations:                  20   AIC:                            -15.77
# Df Residuals:                      13   BIC:                            -8.802
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4914      0.151      3.251      0.006       0.165       0.818
# IFEval         0.0026      0.003      0.900      0.384      -0.004       0.009
# BBH           -0.0011      0.012     -0.090      0.930      -0.026       0.024
# MATH Lvl 5     0.0215      0.009      2.277      0.040       0.001       0.042
# GPQA          -0.0008      0.015     -0.053      0.958      -0.034       0.032
# MUSR           0.0060      0.015      0.387      0.705      -0.027       0.039
# MMLU-PRO      -0.0069      0.011     -0.623      0.544      -0.031       0.017
# ==============================================================================
# Omnibus:                        2.233   Durbin-Watson:                   1.641
# Prob(Omnibus):                  0.327   Jarque-Bera (JB):                1.106
# Skew:                          -0.114   Prob(JB):                        0.575
# Kurtosis:                       1.871   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
for metric in ['faithfulness','answer_relevancy', 'answer_correctness', 'answer_similarity', 'BLEUScore','ROUGEScore', 'BERTScore']:
    y = df_metrics_combined[metric]
    
    X = sm.add_constant(X)
    
    # Fit the linear regression model
    model = sm.OLS(y, X).fit()
    
    # Print the summary of the regression model
    print(metric)
    print(model.summary())
# Out:
# faithfulness
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           faithfulness   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     1.763
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.184
# Time:                        09:47:06   Log-Likelihood:                 14.886
# No. Observations:                  20   AIC:                            -15.77
# Df Residuals:                      13   BIC:                            -8.802
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4914      0.151      3.251      0.006       0.165       0.818
# IFEval         0.0026      0.003      0.900      0.384      -0.004       0.009
# BBH           -0.0011      0.012     -0.090      0.930      -0.026       0.024
# MATH Lvl 5     0.0215      0.009      2.277      0.040       0.001       0.042
# GPQA          -0.0008      0.015     -0.053      0.958      -0.034       0.032
# MUSR           0.0060      0.015      0.387      0.705      -0.027       0.039
# MMLU-PRO      -0.0069      0.011     -0.623      0.544      -0.031       0.017
# ==============================================================================
# Omnibus:                        2.233   Durbin-Watson:                   1.641
# Prob(Omnibus):                  0.327   Jarque-Bera (JB):                1.106
# Skew:                          -0.114   Prob(JB):                        0.575
# Kurtosis:                       1.871   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# answer_relevancy
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       answer_relevancy   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     1.687
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.202
# Time:                        09:47:06   Log-Likelihood:                 23.186
# No. Observations:                  20   AIC:                            -32.37
# Df Residuals:                      13   BIC:                            -25.40
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7028      0.100      7.040      0.000       0.487       0.918
# IFEval         0.0025      0.002      1.300      0.216      -0.002       0.007
# BBH            0.0096      0.008      1.239      0.237      -0.007       0.026
# MATH Lvl 5    -0.0098      0.006     -1.577      0.139      -0.023       0.004
# GPQA          -0.0003      0.010     -0.035      0.973      -0.022       0.021
# MUSR          -0.0165      0.010     -1.625      0.128      -0.038       0.005
# MMLU-PRO      -0.0052      0.007     -0.720      0.484      -0.021       0.010
# ==============================================================================
# Omnibus:                        0.867   Durbin-Watson:                   2.244
# Prob(Omnibus):                  0.648   Jarque-Bera (JB):                0.743
# Skew:                          -0.148   Prob(JB):                        0.690
# Kurtosis:                       2.103   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# answer_correctness
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     answer_correctness   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.9722
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.481
# Time:                        09:47:06   Log-Likelihood:                 35.367
# No. Observations:                  20   AIC:                            -56.73
# Df Residuals:                      13   BIC:                            -49.76
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3092      0.054      5.695      0.000       0.192       0.426
# IFEval         0.0004      0.001      0.365      0.721      -0.002       0.003
# BBH            0.0060      0.004      1.426      0.177      -0.003       0.015
# MATH Lvl 5     0.0017      0.003      0.494      0.630      -0.006       0.009
# GPQA          -0.0038      0.005     -0.701      0.496      -0.016       0.008
# MUSR          -0.0067      0.006     -1.222      0.243      -0.019       0.005
# MMLU-PRO      -0.0044      0.004     -1.114      0.286      -0.013       0.004
# ==============================================================================
# Omnibus:                        5.662   Durbin-Watson:                   2.230
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                1.631
# Skew:                          -0.071   Prob(JB):                        0.442
# Kurtosis:                       1.608   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# answer_similarity
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      answer_similarity   R-squared:                       0.420
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     1.569
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.233
# Time:                        09:47:06   Log-Likelihood:                 29.139
# No. Observations:                  20   AIC:                            -44.28
# Df Residuals:                      13   BIC:                            -37.31
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6657      0.074      8.981      0.000       0.506       0.826
# IFEval         0.0010      0.001      0.702      0.495      -0.002       0.004
# BBH            0.0034      0.006      0.591      0.564      -0.009       0.016
# MATH Lvl 5     0.0002      0.005      0.045      0.965      -0.010       0.010
# GPQA          -0.0050      0.007     -0.677      0.510      -0.021       0.011
# MUSR          -0.0120      0.008     -1.588      0.136      -0.028       0.004
# MMLU-PRO       0.0009      0.005      0.165      0.872      -0.011       0.013
# ==============================================================================
# Omnibus:                        1.782   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.410   Jarque-Bera (JB):                1.255
# Skew:                          -0.601   Prob(JB):                        0.534
# Kurtosis:                       2.748   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BLEUScore
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              BLEUScore   R-squared:                       0.330
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     1.069
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.428
# Time:                        09:47:06   Log-Likelihood:                 64.431
# No. Observations:                  20   AIC:                            -114.9
# Df Residuals:                      13   BIC:                            -107.9
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0193      0.013      1.518      0.153      -0.008       0.047
# IFEval         0.0002      0.000      0.966      0.352      -0.000       0.001
# BBH            0.0007      0.001      0.715      0.487      -0.001       0.003
# MATH Lvl 5     0.0009      0.001      1.113      0.286      -0.001       0.003
# GPQA          -0.0006      0.001     -0.494      0.630      -0.003       0.002
# MUSR          -0.0008      0.001     -0.632      0.538      -0.004       0.002
# MMLU-PRO      -0.0009      0.001     -0.948      0.360      -0.003       0.001
# ==============================================================================
# Omnibus:                        2.853   Durbin-Watson:                   2.321
# Prob(Omnibus):                  0.240   Jarque-Bera (JB):                1.419
# Skew:                           0.304   Prob(JB):                        0.492
# Kurtosis:                       1.845   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ROUGEScore
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ROUGEScore   R-squared:                       0.271
# Model:                            OLS   Adj. R-squared:                 -0.065
# Method:                 Least Squares   F-statistic:                    0.8071
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.582
# Time:                        09:47:06   Log-Likelihood:                 34.281
# No. Observations:                  20   AIC:                            -54.56
# Df Residuals:                      13   BIC:                            -47.59
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2426      0.057      4.232      0.001       0.119       0.366
# IFEval        -0.0010      0.001     -0.875      0.397      -0.003       0.001
# BBH            0.0051      0.004      1.150      0.271      -0.004       0.015
# MATH Lvl 5     0.0024      0.004      0.663      0.519      -0.005       0.010
# GPQA          -0.0088      0.006     -1.527      0.151      -0.021       0.004
# MUSR          -0.0059      0.006     -1.009      0.331      -0.018       0.007
# MMLU-PRO      -0.0025      0.004     -0.591      0.565      -0.011       0.007
# ==============================================================================
# Omnibus:                        4.361   Durbin-Watson:                   2.462
# Prob(Omnibus):                  0.113   Jarque-Bera (JB):                2.720
# Skew:                          -0.892   Prob(JB):                        0.257
# Kurtosis:                       3.289   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# BERTScore
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              BERTScore   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     1.161
# Date:                Thu, 25 Jul 2024   Prob (F-statistic):              0.383
# Time:                        09:47:06   Log-Likelihood:                 52.693
# No. Observations:                  20   AIC:                            -91.39
# Df Residuals:                      13   BIC:                            -84.41
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8474      0.023     37.117      0.000       0.798       0.897
# IFEval         0.0006      0.000      1.288      0.220      -0.000       0.002
# BBH            0.0010      0.002      0.572      0.577      -0.003       0.005
# MATH Lvl 5     0.0013      0.001      0.913      0.378      -0.002       0.004
# GPQA          -0.0009      0.002     -0.377      0.712      -0.006       0.004
# MUSR          -0.0018      0.002     -0.766      0.457      -0.007       0.003
# MMLU-PRO      -0.0014      0.002     -0.839      0.416      -0.005       0.002
# ==============================================================================
# Omnibus:                        0.552   Durbin-Watson:                   2.144
# Prob(Omnibus):                  0.759   Jarque-Bera (JB):                0.590
# Skew:                          -0.047   Prob(JB):                        0.744
# Kurtosis:                       2.163   Cond. No.                         254.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
