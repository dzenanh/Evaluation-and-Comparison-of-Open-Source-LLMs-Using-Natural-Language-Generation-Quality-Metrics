# %%
# %pip install --upgrade --quiet  arxiv
# %pip install --upgrade --quiet  pymupdf

# %%
### Import Packages
import pandas as pd

# %%
import os
from dotenv import load_dotenv

load_dotenv()

### OpenAI
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

from langchain_community.document_loaders import ArxivLoader

# %% [markdown]
# ### Load Documents

# %%
docs = ArxivLoader(query="security penetration testing", load_all_available_meta=True, load_max_docs=200).load()

# %%
from datetime import datetime

security_dataset = []
for i, doc in enumerate(docs):
    published_str = doc.metadata['Published']#'2019-08-01'
    date_object = datetime.strptime(published_str, '%Y-%m-%d').date()

    if date_object > datetime.strptime("2024-04-18", '%Y-%m-%d').date():
        print(i ,", ",date_object," : ", doc.metadata["Title"], " by: ", doc.metadata["Authors"])
        security_dataset.append(doc)
# Out:
# 7 ,  2024-06-02  :  PentestGPT: An LLM-empowered Automatic Penetration Testing Tool  by:  Gelei Deng, Yi Liu, Víctor Mayoral-Vilches, Peng Liu, Yuekang Li, Yuan Xu, Tianwei Zhang, Yang Liu, Martin Pinzger, Stefan Rass
# 35 ,  2024-06-12  :  PTHelper: An open source tool to support the Penetration Testing process  by:  Jacobo Casado de Gracia, Alfonso Sánchez-Macián
# 62 ,  2024-06-08  :  Interactive Greybox Penetration Testing for Cloud Access Control using IAM Modeling and Deep Reinforcement Learning  by:  Yang Hu, Wenxi Wang, Sarfraz Khurshid, Mohit Tiwari
# 75 ,  2024-05-24  :  Knowledge-Informed Auto-Penetration Testing Based on Reinforcement Learning with Reward Machine  by:  Yuanliang Li, Hanzheng Dai, Jun Yan
# 81 ,  2024-05-26  :  Make Safe Decisions in Power System: Safe Reinforcement Learning Based Pre-decision Making for Voltage Stability Emergency Control  by:  Congbo Bi, Lipeng Zhu, Di Liu, Chao Lu
# 85 ,  2024-05-09  :  Artificial Intelligence as the New Hacker: Developing Agents for Offensive Security  by:  Leroy Jacob Valencia
# 90 ,  2024-07-19  :  Bridging the Gap: A Survey and Classification of Research-Informed Ethical Hacking Tools  by:  Paolo Modesti, Lewis Golightly, Louis Holmes, Chidimma Opara, Marco Moscini
# 107 ,  2024-06-25  :  Leveraging Reinforcement Learning in Red Teaming for Advanced Ransomware Attack Simulations  by:  Cheng Wang, Christopher Redino, Ryan Clark, Abdul Rahman, Sal Aguinaga, Sathvik Murli, Dhruv Nandakumar, Roland Rao, Lanxiao Huang, Daniel Radke, Edward Bowen
# 127 ,  2024-04-19  :  The Power of Words: Generating PowerShell Attacks from Natural Language  by:  Pietro Liguori, Christian Marescalco, Roberto Natella, Vittorio Orbinato, Luciano Pianese
# 128 ,  2024-04-22  :  Offensive AI: Enhancing Directory Brute-forcing Attack with the Use of Language Models  by:  Alberto Castagnaro, Mauro Conti, Luca Pajola
# 129 ,  2024-06-19  :  Data Value in Distribution System Operations  by:  Mehrnoush Ghazanfariharandi, Robert Mieth

# %%
len(security_dataset)
# Out:
# 11

# %% [markdown]
# ### Save Documents

# %%
from  langchain.schema import Document
import json
from typing import Iterable

def save_docs_to_jsonl(array:Iterable[Document], file_path:str)->None:
    with open(file_path, 'w') as jsonl_file:
        for doc in array:
            jsonl_file.write(doc.json() + '\n')

def load_docs_from_jsonl(file_path)->Iterable[Document]:
    array = []
    with open(file_path, 'r') as jsonl_file:
        for line in jsonl_file:
            data = json.loads(line)
            obj = Document(**data)
            array.append(obj)
    return array
    
save_docs_to_jsonl(security_dataset,'./security_dataset2.jsonl')


docs2=load_docs_from_jsonl('./security_dataset2.jsonl')

print(len(docs2))
# Out:
# 11

# %% [markdown]
# ### Generate Q&A

# %%
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# generator with openai models
generator_llm = ChatOpenAI(model="gpt-4o")
critic_llm = ChatOpenAI(model="gpt-4o")
embeddings = OpenAIEmbeddings()

generator = TestsetGenerator.from_langchain(
    generator_llm,
    critic_llm,
    embeddings
)

# Change resulting question type distribution
distributions = {
    simple: 0.4,
    multi_context: 0.4,
    reasoning: 0.2
}

# use generator.generate_with_llamaindex_docs if you use llama-index as document loader
testset = generator.generate_with_langchain_docs(docs2, 60, distributions) 
security_qna_dataset = testset.to_pandas()
security_qna_dataset
# Out:
# embedding nodes:   0%|          | 0/462 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/60 [00:00<?, ?it/s]
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#                                              question  \
# 0   What metrics are used to assess the syntactic ...
# 1   How did GPT-3.5 perform in end-to-end penetrat...
# 2   What is the performance of PENTESTGPT in the p...
# 3   How does AI-driven command generation enhance ...
# 4   How was PThelper functionality validated in a ...
# 5   How does the availability of source code refle...
# 6   What is the process for generating a Type-II p...
# 7   How does tree reconstruction help in understan...
# 8   How are large language models (LLMs) being uti...
# 9   How does GPT-4 perform in completing attack ta...
# 10  How does VAPE-BRIDGE facilitate the integratio...
# 11  How does the Deep Q-learning with RM algorithm...
# 12  What vulnerability did the tool discover on th...
# 13  How does the gap between industry and academia...
# 14  What are the stages of a cyberattack as deline...
# 15  How does pre-decision making contribute to saf...
# 16  What are some applications of safe reinforceme...
# 17  What challenges do adaptive emergency control ...
# 18  What is the application of Deep Bayesian Activ...
# 19  How can Large Language Models (LLMs) be levera...
# 20  What does jailbreaking in LLMs involve and why...
# 21  How does the DRLRM-PT framework utilize cybers...
# 22  What is the significance of TAC being the firs...
# 23  How is generative AI being utilized to enhance...
# 24  How does Comp. Syntax Accuracy handle parse er...
# 25  How do BLEU-4 scores and GPT-4's performance i...
# 26  How does Vulsploit use tools and VM benchmarks...
# 27  How do ReaperAI's adaptive decision-making and...
# 28  How do Metasploitable VMs aid vuln detection/e...
# 29  How does AUTOATTACKER's modular design tackle ...
# 30  How does GPT-3.5-turbo's extended token capaci...
# 31  How do LLMs' attention limits affect their rol...
# 32  How do chosen LLMs fare on pen testing benchma...
# 33  How does the critical load shedding threshold ...
# 34  How does AUTOATTACKER use LLMs for multi-stage...
# 35  How does PTHelper's modular design and black-b...
# 36  How do Python wrappers and task trees boost AI...
# 37  How does TAC's RL-based query optimization enh...
# 38  How does gpt-turbo-4-preview boost PENTESTGPT'...
# 39  Which AWS IAM tools using formal methods and S...
# 40  How do SRL and AL improve security margin esti...
# 41  How do SRL frameworks tackle high renewable en...
# 42  How does lack of local reactive power support ...
# 43  How does ReaperAI use GPT-4 in Python to find ...
# 44  How do the agent's actions and observations in...
# 45  How do JSON prompts and subprocess piping impr...
# 46  How do current auto security test limits and t...
# 47  How do probabilistic models and LLMs boost dir...
# 48  How do auto-grade MCUs and remote access speed...
# 49  Which 119.2B token GitHub dataset is used to p...
# 50  How does the context size limiter save costs w...
# 51  Which pre-trained models on Python and Java ar...
# 52  How does the tool assess LLMs in Linux priv. e...
# 53  Which framework uses logic programming to dete...
# 54  How do DFS and BFS differ in directory brute-f...
# 55  How does TAC's whitebox vs. greybox compare in...
# 56  How does pre-decision making boost the securit...
# 57  How does UE Sec Reloaded boost Open5GS & srsRA...
# 58  How did Llama2's suid binaries and cmd params ...
#
#                                              contexts  \
# 0   [ PowerShell code. Both the generated commands...
# 1   [ to assess the performances of various LLMs i...
# 2   [\ndesign, which retains the full testing cont...
# 3   [Figure 4.2: Example Task Tree\n4.4.2\nDynamic...
# 4   [ only chatgpt NLPAgent is available.\n• Type ...
# 5   [\n100.00%\n(b) Source Code Available\nTable 4...
# 6   [\nmission; for each entity with one of these ...
# 7   [ a set of directories utilized\nin a brute-fo...
# 8   [ www.makotemplates.org/. Accessed: April 16, ...
# 9   [ avoid potential out-of-\nthe-box attacks by ...
# 10  [ TAMELESS can analyse threats, verify securit...
# 11  [ as network scanning,\nexploiting vulnerabili...
# 12  [ each of the hosts generated more than 20 fin...
# 13  [Bridging the Gap: A Survey and Classification...
# 14  [24], a state-of-the-art Large Language\nModel...
# 15  [ enhances the security margin\nestimator’s tr...
# 16  [ection and Control, vol. 43, no. 4, pp. 102–1...
# 17  [1\nMake Safe Decisions in Power System: Safe\...
# 18  [a, C. Zheng, P.-C. Chen, T. Popovic, and M. K...
# 19  [ARTIFICIAL INTELLIGENCE AS THE NEW HACKER:\nD...
# 20  [, which are reviewed below.\nJailbreaking in ...
# 21  [ the DQN agents. Specifically, the average nu...
# 22  [box variants of TAC,\neach of which employs a...
# 23  [ at training time.\nExamples of LM Patterns. ...
# 24  [ PowerShell code. Both the generated commands...
# 25  [\n• CodeGen [17], an autoregressive language ...
# 26  [UDDY: A Scalable Approach for Vulnerable Code...
# 27  [ quality while ensuring communication upstrea...
# 28  [ only chatgpt NLPAgent is available.\n• Type ...
# 29  [elligence, vol. 35, no. 5, pp. 649–663, 2023....
# 30  [able to find all file-based vulnerabilities —...
# 31  [ al. [2024]\nCreativity is a critical asset i...
# 32  [ to assess the performances of various LLMs i...
# 33  [Critically \nStable\nAfter \nfailed \nUVLS\n×...
# 34  [ avoid potential out-of-\nthe-box attacks by ...
# 35  [ provides more time to focus on other phases ...
# 36  [. As\nof April 22, 2024, the rate per one mil...
# 37  [ detection, TAC represents IAM configurations...
# 38  [24], a state-of-the-art Large Language\nModel...
# 39  [ detection, TAC represents IAM configurations...
# 40  [ enhances the security margin\nestimator’s tr...
# 41  [ection and Control, vol. 43, no. 4, pp. 102–1...
# 42  [A. Overall Framework\nThe overall framework o...
# 43  [ARTIFICIAL INTELLIGENCE AS THE NEW HACKER:\nD...
# 44  [ consisting of seven components ⟨S, A, O, T(s...
# 45  [\nFigure4.6, the LLM is equipped to reflect o...
# 46  [Towards a New Configurable and Practical\nRem...
# 47  [ at training time.\nExamples of LM Patterns. ...
# 48  [aims to discover as much information about th...
# 49  [\n• CodeGen [17], an autoregressive language ...
# 50  [ system, deploy vulnerabilities\nupdate syste...
# 51  [ framework, ensuring\nthat the PowerShell com...
# 52  [LLMs as Hackers: Autonomous Linux Privilege E...
# 53  [ Press, W. Merrill, A. Liu, and N. A.\nSmith,...
# 54  [ a set of directories utilized\nin a brute-fo...
# 55  [box variants of TAC,\neach of which employs a...
# 56  [ enhances the security margin\nestimator’s tr...
# 57  [ TAMELESS can analyse threats, verify securit...
# 58  [” query.\nThe results of test-runs containing...
#
#                                          ground_truth evolution_type  \
# 0   The metrics used to assess the syntactic quali...         simple
# 1   GPT-3.5 successfully completed 1 end-to-end pe...         simple
# 2   PENTESTGPT's performance in the picoMini CTF c...         simple
# 3   AI-driven command generation enhances the effi...         simple
# 4   PThelper functionality was validated in a simu...         simple
# 5   The availability of source code for more than ...         simple
# 6   For each entity with one of the specified type...         simple
# 7   Tree reconstruction helps in understanding the...         simple
# 8   Large language models (LLMs) are being utilize...         simple
# 9   GPT-4 achieves a perfect success rate in compl...         simple
# 10  VAPE-BRIDGE facilitates the integration betwee...         simple
# 11  The Deep Q-learning with RM algorithm (DQRM) t...         simple
# 12  The tool discovered the vulnerability CVE-2017...         simple
# 13  The gap between industry and academia in devel...         simple
# 14  The stages of a cyberattack as delineated by t...         simple
# 15  Pre-decision making contributes to safeguardin...         simple
# 16  Some applications of safe reinforcement learni...         simple
# 17  Adaptive emergency control strategies face sig...         simple
# 18  Deep Bayesian Active Learning is applied in po...         simple
# 19  Large Language Models (LLMs) such as GPT-4 can...         simple
# 20  Jailbreaking in LLMs involves circumventing bu...         simple
# 21  The DRLRM-PT framework utilizes RMs to embed d...         simple
# 22  The significance of TAC being the first intera...         simple
# 23  Generative AI is being utilized to enhance dir...         simple
# 24  Comparative Syntax Accuracy assesses the synta...  multi_context
# 25                                                nan  multi_context
# 26  Vulsploit is a semi-automatic penetration test...  multi_context
# 27  ReaperAI's adaptive decision-making and natura...  multi_context
# 28  Metasploitable VMs aid vulnerability detection...  multi_context
# 29  AUTOATTACKER's modular design tackles hands-on...  multi_context
# 30  GPT-3.5-turbo benefits from the extended token...  multi_context
# 31  LLMs typically lack situational awareness, whi...  multi_context
# 32  The chosen LLMs demonstrate proficiency in man...  multi_context
# 33  The critical load shedding threshold is the mi...  multi_context
# 34  AUTOATTACKER uses LLMs for multi-stage cyber-a...  multi_context
# 35  PTHelper's modular design and black-box suppor...  multi_context
# 36  Python wrappers and task trees enhance AI's de...  multi_context
# 37  TAC's RL-based query optimization enhances gre...  multi_context
# 38                                                nan  multi_context
# 39                                                nan  multi_context
# 40  SRL (Safe Reinforcement Learning) and AL (Acti...  multi_context
# 41  SRL frameworks tackle high renewable energy an...  multi_context
# 42  Lack of local reactive power support often lea...  multi_context
# 43  ReaperAI leverages the capabilities of Large L...  multi_context
# 44  The agent's actions and observations interact ...  multi_context
# 45  JSON and structured prompts serve as the main ...  multi_context
# 46  Current auto security test limits and third-pa...  multi_context
# 47                                                nan  multi_context
# 48  Auto-grade MCUs and remote access speed up ECU...      reasoning
# 49  The 119.2B token GitHub dataset used to pre-tr...      reasoning
# 50  The context size limiter saves costs with LLMs...      reasoning
# 51  The pre-trained models on Python and Java used...      reasoning
# 52  The tool assesses LLMs in Linux privilege esca...      reasoning
# 53  Halluvault is the framework that uses logic pr...      reasoning
# 54                                                nan      reasoning
# 55  TAC’s whitebox variant successfully detected a...      reasoning
# 56  Pre-decision making boosts the security margin...      reasoning
# 57  UE Security Reloaded enhances existing open-so...      reasoning
# 58  Llama2 was able to identify potential suid bin...      reasoning
#
#                                              metadata  episode_done
# 0   [{'Published': '2024-04-19', 'Title': 'The Pow...          True
# 1   [{'Published': '2024-06-02', 'Title': 'Pentest...          True
# 2   [{'Published': '2024-06-02', 'Title': 'Pentest...          True
# 3   [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 4   [{'Published': '2024-06-12', 'Title': 'PTHelpe...          True
# 5   [{'Published': '2024-07-19', 'Title': 'Bridgin...          True
# 6   [{'Published': '2024-06-08', 'Title': 'Interac...          True
# 7   [{'Published': '2024-04-22', 'Title': 'Offensi...          True
# 8   [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 9   [{'Published': '2024-03-02', 'Title': 'AutoAtt...          True
# 10  [{'Published': '2024-07-19', 'Title': 'Bridgin...          True
# 11  [{'Published': '2024-05-24', 'Title': 'Knowled...          True
# 12  [{'Published': '2024-06-12', 'Title': 'PTHelpe...          True
# 13  [{'Published': '2024-07-19', 'Title': 'Bridgin...          True
# 14  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 15  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 16  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 17  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 18  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 19  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 20  [{'Published': '2024-03-02', 'Title': 'AutoAtt...          True
# 21  [{'Published': '2024-05-24', 'Title': 'Knowled...          True
# 22  [{'Published': '2024-06-08', 'Title': 'Interac...          True
# 23  [{'Published': '2024-04-22', 'Title': 'Offensi...          True
# 24  [{'Published': '2024-04-19', 'Title': 'The Pow...          True
# 25  [{'Published': '2024-04-19', 'Title': 'The Pow...          True
# 26  [{'Published': '2024-07-19', 'Title': 'Bridgin...          True
# 27  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 28  [{'Published': '2024-06-12', 'Title': 'PTHelpe...          True
# 29  [{'Published': '2024-03-02', 'Title': 'AutoAtt...          True
# 30  [{'Published': '2024-03-19', 'Title': 'LLMs as...          True
# 31  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 32  [{'Published': '2024-06-02', 'Title': 'Pentest...          True
# 33  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 34  [{'Published': '2024-03-02', 'Title': 'AutoAtt...          True
# 35  [{'Published': '2024-06-12', 'Title': 'PTHelpe...          True
# 36  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 37  [{'Published': '2024-06-08', 'Title': 'Interac...          True
# 38  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 39  [{'Published': '2024-06-08', 'Title': 'Interac...          True
# 40  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 41  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 42  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 43  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 44  [{'Published': '2024-05-24', 'Title': 'Knowled...          True
# 45  [{'Published': '2024-05-09', 'Title': 'Artific...          True
# 46  [{'Published': '2024-04-02', 'Title': 'Towards...          True
# 47  [{'Published': '2024-04-22', 'Title': 'Offensi...          True
# 48  [{'Published': '2024-04-02', 'Title': 'Towards...          True
# 49  [{'Published': '2024-04-19', 'Title': 'The Pow...          True
# 50  [{'Published': '2024-03-19', 'Title': 'LLMs as...          True
# 51  [{'Published': '2024-04-19', 'Title': 'The Pow...          True
# 52  [{'Published': '2024-03-19', 'Title': 'LLMs as...          True
# 53  [{'Published': '2024-06-02', 'Title': 'Pentest...          True
# 54  [{'Published': '2024-04-22', 'Title': 'Offensi...          True
# 55  [{'Published': '2024-06-08', 'Title': 'Interac...          True
# 56  [{'Published': '2024-05-26', 'Title': 'Make Sa...          True
# 57  [{'Published': '2024-07-19', 'Title': 'Bridgin...          True
# 58  [{'Published': '2024-03-19', 'Title': 'LLMs as...          True

# %%
security_qna_dataset = security_qna_dataset[security_qna_dataset['ground_truth'] != 'nan']
security_qna_dataset = security_qna_dataset.sample(n=50, random_state=1)

# %%
len(security_qna_dataset)
# Out:
# 50

# %%
security_qna_dataset.to_csv("./benchmark-security2.csv", index=False)
